# %% [markdown]
# #### Problem Statement
#
#
# Extending linear model with Basis functions

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

# %%
ice_cream_sales_data = pd.read_csv("../../dataset/ice-cream-sales-data.csv")
display(ice_cream_sales_data.describe())
# Out:
#        Temperature (°C)  Ice Cream Sales (units)
# count         49.000000                49.000000
# mean           0.271755                15.905308
# std            2.697672                12.264682
# min           -4.662263                 0.328626
# 25%           -2.111870                 4.857988
# 50%            0.688781                12.615181
# 75%            2.784836                25.142082
# max            4.899032                41.842986

# %%
sns.jointplot(x="Temperature (°C)", y="Ice Cream Sales (units)", data=ice_cream_sales_data, kind="reg")

# %%
sns.lmplot(x="Temperature (°C)", y="Ice Cream Sales (units)", data=ice_cream_sales_data)
